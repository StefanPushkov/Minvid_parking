# %%
import requests

# %%
r = requests.get('http://droplak.ru/wp-content/uploads/2016/04/1-8.jpg')

# %%
r.content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xdb\x00C\x00\x04\x03\x03\x04\x03\x03\x04\x04\x03\x04\x05\x04\x04\x05\x06\n\x07\x06\x06\x06\x06\r\t\n\x08\n\x0f\r\x10\x10\x0f\r\x0f\x0e\x11\x13\x18\x14\x11\x12\x17\x12\x0e\x0f\x15\x1c\x15\x17\x19\x19\x1b\x1b\x1b\x10\x14\x1d\x1f\x1d\x1a\x1f\x18\x1a\x1b\x1a\xff\xdb\x00C\\\x02\\\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1d\x00\x00\x01\x04\x03\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x06\x04\x05\x07\x08\x01\x02\x03\t\x00\xff\xc4\x00^\x10\x00\x01\x03\x02\x04\x03\x05\x04\x06\x07\x03\x06\n\x06\x08\x07\x01\x02\x03\x11\x00\x04\x05\x12!1\x06AQ\x07\x13"aq\x142\x81\x91\x08#\xa1\xb1\xd1\xf0\x153BRb\xc1\xe1$r\x92CSc\x93\xb2\xf1\t\x16\x17
# ...

# %%
import requests
r = requests.get("https://stackoverflow.com") 
data = r.content  # Content of response

print(r.status_code)
print(data)
# Out:
# 200
# ...
